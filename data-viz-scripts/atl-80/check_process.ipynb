# %%
import numpy as np

# %%
age_data = np.load('current_infectious_Age.npy')
true_data = np.load('current_infectious_Ground.npy')

# %%
age_data.shape
# Out:
# (27, 8640)

# %%
true_data.shape
# Out:
# (27, 8640)

# %%
age_data[2,:].sum()
# Out:
# 545068.0

# %%
true_data[2,:].sum()
# Out:
# 1028286.0

# %%
for i in range(27):
    print(age_data[i,:].sum()/true_data[i,:].sum())
# Out:
# 0.2817883187701202
# 0.23468760570584693
# 0.29883731591821283
# 0.36944833875512123
# 0.2947270754655458
# 0.2979650782863267
# 0.26693994203520827
# 0.17584007228081866
# 0.2246169770485633
# 0.2499135580634739
# 0.24403079944811631
# 0.23770055646245006
# 0.19830355776912748
# 0.5507504894496411
# 0.17102973537211533
# 0.1899530243935108
# 0.26241846179856015
# 0.2655668363885306
# 0.27567905401182485
# 0.2569652462395723
# 0.3145866249025466
# 0.2339214652710601
# 0.3018525092485333
# 0.24772415600705805
# 0.2594510912410697
# 0.3053350764154761
# 0.3316030356704203

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(age_data, cmap='hot', interpolation='nearest')

# %%
import seaborn as sns

# %%
ax =sns.heatmap(age_data, linewidth=0.5)
plt.show()
