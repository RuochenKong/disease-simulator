# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
DATADIR = "../examples/logs/logs/"
DATASUFIX = "%sbias_%d_%d_DiseaseStatus.tsv"
AGENTPROFILE = "%sbias_%d_%d_patterns_of_life.log"

# %%
fulldata = pd.read_csv(DATASUFIX%(DATADIR,2000,90), sep = "\t|,", engine='python')

# %%
infectiousAgents = fulldata[fulldata['diseaseStatus'] == 'Infectious']
recoveredAgents = fulldata[fulldata['diseaseStatus'] == 'Recovered']
# Out:
#        step  agentId [resRegion diseaseStatus  byAgentID  \
# 2084   1521      589       [112     Recovered        NaN
# 2094   1580       17        [27     Recovered        NaN
# 2102   1620     1340       [208     Recovered        NaN
# 2119   1662     1571       [258     Recovered        NaN
# 2135   1733      979       [162     Recovered        NaN
# ...     ...      ...        ...           ...        ...
# 3960  16884     1131       [174     Recovered        NaN
# 3971  17335     1700       [268     Recovered        NaN
# 3984  18315      499       [112     Recovered        NaN
# 4008  19412      474       [112     Recovered        NaN
# 4016  19883     1797       [268     Recovered        NaN
#
#                          time                                      location  \
# 2084  2019-07-06T06:45:00.000    POINT (742414.4208981143 3738614.81391764)
# 2094  2019-07-06T11:40:00.000   POINT (740485.0914292916 3737195.214770876)
# ...
